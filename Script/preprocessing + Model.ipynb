# %%
import pandas as pd
import numpy as np
import re
from sklearn.feature_extraction.text import CountVectorizer
#computes the similarity between the enterd value and the valus in our df
from sklearn.metrics.pairwise import cosine_similarity
df = pd.read_csv('../Data/skindataall.csv')

# %%
df.head()
# Out:
#    Unnamed: 0    Username Skin_Tone    Skin_Type Eye_Color Hair_Color  \
# 0           0      allyp3    Medium  Combination     Brown   Brunette
# 1           1      PatTea    Medium  Combination     Brown        Red
# 2           2    Sabi1991   No data      No data   No data    No data
# 3           3  happyface2      Fair          Dry      Blue     Blonde
# 4           4    kimkix34      Fair       Normal     Green     Blonde
#
#    Rating_Stars                                             Review  \
# 0             5  This is hands down the best cleanser I’ve ever...
# 1             1  Unfortunately this doesn’t work for everyone. ...
# 2             5  My favorite cleanser!! i love the packaging on...
# 3             5  I love all things Youth To The People! This cl...
# 4             5  I had a trial size of this and was obsessed. M...
#
#                           Product                Brand  ...  Oily  Sensitive  \
# 0  Superfood Antioxidant Cleanser  YOUTH TO THE PEOPLE  ...     0          0
# 1  Superfood Antioxidant Cleanser  YOUTH TO THE PEOPLE  ...     0          0
# 2  Superfood Antioxidant Cleanser  YOUTH TO THE PEOPLE  ...     0          0
# 3  Superfood Antioxidant Cleanser  YOUTH TO THE PEOPLE  ...     0          0
# 4  Superfood Antioxidant Cleanser  YOUTH TO THE PEOPLE  ...     0          0
#
#    Category                                        Product_Url  User_id  \
# 0  Cleanser  https://www.sephora.com/product/kale-spinach-g...     3420
# 1  Cleanser  https://www.sephora.com/product/kale-spinach-g...     2483
# 2  Cleanser  https://www.sephora.com/product/kale-spinach-g...     2715
# 3  Cleanser  https://www.sephora.com/product/kale-spinach-g...     4497
# 4  Cleanser  https://www.sephora.com/product/kale-spinach-g...     5017
#
#    Product_id                                Ingredients_Cleaned  \
# 0         157  ['sodium', 'cocoyl', 'glutamate', 'cocamidopro...
# 1         157  ['sodium', 'cocoyl', 'glutamate', 'cocamidopro...
# 2         157  ['sodium', 'cocoyl', 'glutamate', 'cocamidopro...
# 3         157  ['sodium', 'cocoyl', 'glutamate', 'cocamidopro...
# 4         157  ['sodium', 'cocoyl', 'glutamate', 'cocamidopro...
#
#                                       Review_Cleaned Good_Stuff  \
# 0  ['hand', 'best', 'cleanser', 'ever', 'used', '...          1
# 1  ['unfortunately', 'work', 'everyone', 'used', ...          0
# 2  ['favorite', 'cleanser', 'love', 'packaging', ...          1
# 3  ['love', 'thing', 'youth', 'people', 'cleanser...          1
# 4  ['trial', 'size', 'wa', 'obsessed', 'skin', 'f...          1
#
#                                            Ing_Tfidf
# 0  sodium, cocoyl, glutamate, cocamidopropyl, bet...
# 1  sodium, cocoyl, glutamate, cocamidopropyl, bet...
# 2  sodium, cocoyl, glutamate, cocamidopropyl, bet...
# 3  sodium, cocoyl, glutamate, cocamidopropyl, bet...
# 4  sodium, cocoyl, glutamate, cocamidopropyl, bet...
#
# [5 rows x 26 columns]

# %% [markdown]
# # preparin data

# %%
#removing unwanted col
df.drop('Skin_Tone', inplace=True, axis=1)
df.drop('Eye_Color', inplace=True, axis=1)
df.drop('Hair_Color', inplace=True, axis=1)
df.drop('Product_Url', inplace=True, axis=1)
df.drop('Username', inplace=True, axis=1)
df.drop('Good_Stuff', inplace=True, axis=1)
df.drop('Ingredients', inplace=True, axis=1)
df.drop('Unnamed: 0', inplace=True, axis=1)
df.drop('Review_Cleaned', inplace=True, axis=1)
df.drop('Price', inplace=True, axis=1)
df.drop('User_id', inplace=True, axis=1)
df.drop('Review', inplace=True, axis=1)
df.drop('Skin_Type', inplace=True, axis=1)

# %%
#drop the face mask 
df = df[~df.Category.str.match('Face Mask')]

# %%
#checking duplicates
df.duplicated(subset='Product_id').sum()
# Out:
# 8311

# %%
#removing them
df = df.drop_duplicates(subset='Product_id')

# %%
#checking if they were removed
df.duplicated(subset='Product_id').sum()
# Out:
# 0

# %%
df.reset_index(drop=True)
# Out:
#      Rating_Stars                                            Product  \
# 0               5                     Superfood Antioxidant Cleanser
# 1               5                      Cleansing & Exfoliating Wipes
# 2               5                        Purity Made Simple Cleanser
# 3               5                        Beste™ No. 9 Jelly Cleanser
# 4               5              The Rice Polish Foaming Enzyme Powder
# ..            ...                                                ...
# 309             1      Midnight Secret Late Night Recovery Treatment
# 310             5                      Post-Acne Spot Lightening Gel
# 311             2    Hydro-Plumping Re-Texturizing Serum Concentrate
# 312             5                 The Microdelivery Resurfacing Peel
# 313             5  Ferulic + Retinol Wrinkle Recovery Overnight S...
#
#                          Brand  Rating  Combination  Dry  Normal  Oily  \
# 0          YOUTH TO THE PEOPLE     4.4            0    0       0     0
# 1           SEPHORA COLLECTION     4.5            0    0       0     0
# 2                   PHILOSOPHY     4.5            1    1       1     1
# 3               DRUNK ELEPHANT     4.1            1    0       1     1
# 4                       TATCHA     4.4            1    1       1     1
# ..                         ...     ...          ...  ...     ...   ...
# 309                   GUERLAIN     4.2            1    1       1     1
# 310                      MURAD     3.7            0    0       0     0
# 311         KIEHL'S SINCE 1851     4.7            0    0       0     0
# 312                 PHILOSOPHY     4.7            0    0       0     0
# 313  DR. DENNIS GROSS SKINCARE     4.4            1    1       1     1
#
#      Sensitive     Category  Product_id  \
# 0            0     Cleanser         157
# 1            0     Cleanser          65
# 2            1     Cleanser         210
# 3            1     Cleanser          35
# 4            1     Cleanser         196
# ..         ...          ...         ...
# 309          1  Moisturizer         173
# 310          0    Treatment         198
# 311          0    Treatment         150
# 312          0    Treatment         266
# 313          1  Moisturizer         124
#
#                                    Ingredients_Cleaned  \
# 0    ['sodium', 'cocoyl', 'glutamate', 'cocamidopro...
# 1    ['caprylic', 'capric', 'triglyceride', 'fragra...
# 2    ['sodium', 'lauroamphoacetate', 'sodium', 'tri...
# 3    ['sodium', 'lauroyl', 'methyl', 'isethionate',...
# 4    ['microcrystalline', 'cellulose', 'oryza', 'sa...
# ..                                                 ...
# 309                  ['visit', 'guerlain', 'boutique']
# 310  ['alcohol', 'denat', 'glycolic', 'acid', 'buty...
# 311  ['glycerin', 'dimethicone', 'propanediol', 'di...
# 312  ['microdelivery', 'peel', 'step', 'peg', 'sodi...
# 313  ['dicaprylyl', 'carbonate', 'niacinamide', 'ce...
#
#                                              Ing_Tfidf
# 0    sodium, cocoyl, glutamate, cocamidopropyl, bet...
# 1    caprylic, capric, triglyceride, fragrance, phe...
# 2    sodium, lauroamphoacetate, sodium, trideceth, ...
# 3    sodium, lauroyl, methyl, isethionate, glycerin...
# 4    microcrystalline, cellulose, oryza, sativa, ri...
# ..                                                 ...
# 309                          visit, guerlain, boutique
# 310  alcohol, denat, glycolic, acid, butylene, glyc...
# 311  glycerin, dimethicone, propanediol, dimethicon...
# 312  microdelivery, peel, step, peg, sodium, bicarb...
# 313  dicaprylyl, carbonate, niacinamide, cetyl, alc...
#
# [314 rows x 13 columns]

# %%
#clean Ingredients_Cleaned more
df.replace(',','', regex=True, inplace=True)

# %%
df.head()
# Out:
#      Rating_Stars                                Product                Brand  \
# 0               5         Superfood Antioxidant Cleanser  YOUTH TO THE PEOPLE
# 48              5          Cleansing & Exfoliating Wipes   SEPHORA COLLECTION
# 96              5            Purity Made Simple Cleanser           PHILOSOPHY
# 144             5            Beste™ No. 9 Jelly Cleanser       DRUNK ELEPHANT
# 192             5  The Rice Polish Foaming Enzyme Powder               TATCHA
#
#      Rating  Combination  Dry  Normal  Oily  Sensitive  Category  Product_id  \
# 0       4.4            0    0       0     0          0  Cleanser         157
# 48      4.5            0    0       0     0          0  Cleanser          65
# 96      4.5            1    1       1     1          1  Cleanser         210
# 144     4.1            1    0       1     1          1  Cleanser          35
# 192     4.4            1    1       1     1          1  Cleanser         196
#
#                                    Ingredients_Cleaned  \
# 0    ['sodium' 'cocoyl' 'glutamate' 'cocamidopropyl...
# 48   ['caprylic' 'capric' 'triglyceride' 'fragrance...
# 96   ['sodium' 'lauroamphoacetate' 'sodium' 'tridec...
# 144  ['sodium' 'lauroyl' 'methyl' 'isethionate' 'gl...
# 192  ['microcrystalline' 'cellulose' 'oryza' 'sativ...
#
#                                              Ing_Tfidf
# 0    sodium cocoyl glutamate cocamidopropyl betaine...
# 48   caprylic capric triglyceride fragrance phenoxy...
# 96   sodium lauroamphoacetate sodium trideceth sulf...
# 144  sodium lauroyl methyl isethionate glycerin coc...
# 192  microcrystalline cellulose oryza sativa rice p...

# %%
#remove zeros and change one to col names in new col 

# changing data types of compatibility columns from int to str so we can manipulate them
df = df.astype({'Combination':'string','Dry':'string','Normal':'string','Oily':'string','Sensitive':'string'})

#replacing all 1's with col name 
# #Combination	Dry	Normal	Oily	Sensitive
df['Combination'] = df['Combination'].str.replace('1','combinational')
df['Combination'] = df['Combination'].str.replace('0',' ')

df['Dry'] = df['Dry'].str.replace('1','dry')
df['Dry'] = df['Dry'].str.replace('0',' ')


df['Normal'] = df['Normal'].str.replace('1','normal')
df['Normal'] = df['Normal'].str.replace('0',' ')


df['Oily'] = df['Oily'].str.replace('1','oily')
df['Oily'] = df['Oily'].str.replace('0',' ')


df['Sensitive'] = df['Sensitive'].str.replace('1','sensitive')
df['Sensitive'] = df['Sensitive'].str.replace('0',' ')

#Adding Skin sutibility column to combine what the product is good for as a feature 
df['Skin_sutibility'] = df['Combination'].map(str) + ' ' + df['Dry'].map(str) + ' ' + df['Normal'].map(str)+ ' ' + df['Oily'].map(str) + ' ' +df['Sensitive'].map(str)

# %%
df.head(5)
# Out:
#      Rating_Stars                                Product                Brand  \
# 0               5         Superfood Antioxidant Cleanser  YOUTH TO THE PEOPLE
# 48              5          Cleansing & Exfoliating Wipes   SEPHORA COLLECTION
# 96              5            Purity Made Simple Cleanser           PHILOSOPHY
# 144             5            Beste™ No. 9 Jelly Cleanser       DRUNK ELEPHANT
# 192             5  The Rice Polish Foaming Enzyme Powder               TATCHA
#
#      Rating    Combination  Dry  Normal  Oily  Sensitive  Category  \
# 0       4.4                                               Cleanser
# 48      4.5                                               Cleanser
# 96      4.5  combinational  dry  normal  oily  sensitive  Cleanser
# 144     4.1  combinational       normal  oily  sensitive  Cleanser
# 192     4.4  combinational  dry  normal  oily  sensitive  Cleanser
#
#      Product_id                                Ingredients_Cleaned  \
# 0           157  ['sodium' 'cocoyl' 'glutamate' 'cocamidopropyl...
# 48           65  ['caprylic' 'capric' 'triglyceride' 'fragrance...
# 96          210  ['sodium' 'lauroamphoacetate' 'sodium' 'tridec...
# 144          35  ['sodium' 'lauroyl' 'methyl' 'isethionate' 'gl...
# 192         196  ['microcrystalline' 'cellulose' 'oryza' 'sativ...
#
#                                              Ing_Tfidf  \
# 0    sodium cocoyl glutamate cocamidopropyl betaine...
# 48   caprylic capric triglyceride fragrance phenoxy...
# 96   sodium lauroamphoacetate sodium trideceth sulf...
# 144  sodium lauroyl methyl isethionate glycerin coc...
# 192  microcrystalline cellulose oryza sativa rice p...
#
#                              Skin_sutibility
# 0
# 48
# 96   combinational dry normal oily sensitive
# 144    combinational   normal oily sensitive
# 192  combinational dry normal oily sensitive

# %%
#making the product name in lower case because the user will probably enter it that way
df['Product'] = df['Product'].str.lower()

# %%
#now we remove the extra columns does it have to be 
df.drop(['Rating','Combination','Dry','Normal','Oily','Sensitive','Ingredients_Cleaned'],inplace=True,axis=1)

# %% [markdown]
# #

# %% [markdown]
# ### combining important features

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 314 entries, 0 to 8626
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Rating_Stars     314 non-null    int64
#  1   Product          314 non-null    object
#  2   Brand            314 non-null    object
#  3   Category         314 non-null    object
#  4   Product_id       314 non-null    int64
#  5   Ing_Tfidf        314 non-null    object
#  6   Skin_sutibility  314 non-null    object
# dtypes: int64(2), object(5)
# memory usage: 19.6+ KB

# %%
#checking fo null values
df.isnull().values.any()
# Out:
# False

# %%
#changing the index of some columns so that we dont add them in the combined data col
df = df [['Product_id','Product','Rating_Stars','Brand', 'Category','Skin_sutibility','Ing_Tfidf']]

# %%
df.sample(5)
# Out:
#       Product_id                                            Product  \
# 6273         165                                       matcha toner
# 3713          64                                           cleanser
# 4044         275                         time release acne cleanser
# 2205          93  dr. andrew weil for origins™ mega-bright spf 3...
# 8200         139                                      glycolic peel
#
#       Rating_Stars        Brand     Category  \
# 6273             4  MILK MAKEUP     Cleanser
# 3713             5      EVE LOM     Cleanser
# 4044             5        MURAD     Cleanser
# 2205             5      ORIGINS  Moisturizer
# 8200             5     CAUDALIE    Treatment
#
#                               Skin_sutibility  \
# 6273  combinational dry normal oily sensitive
# 3713  combinational dry normal oily sensitive
# 4044  combinational dry normal oily sensitive
# 2205          combinational dry normal oily
# 8200  combinational dry normal oily sensitive
#
#                                               Ing_Tfidf  \
# 6273  butylene glycol bi peg methyl ether dimethyl s...
# 3713  paraffinum liquidum peg lanolin cetearyl alcoh...
# 4044  disodium cocoamphodiacetate glycerin cetyl alc...
# 2205  butyloctyl salicylate behenyl alcohol nylon oc...
# 8200  glycerin isononyl isononanoate sorbitan steara...
#
#                                           combined_data
# 6273  Cleanser combinational dry normal oily sensiti...
# 3713  Cleanser combinational dry normal oily sensiti...
# 4044  Cleanser combinational dry normal oily sensiti...
# 2205  Moisturizer combinational dry normal oily   bu...
# 8200  Treatment combinational dry normal oily sensit...

# %%
#creating a column with the important features 
df['combined_data'] = df[df.columns[4:]].apply( 
    lambda x: ' '.join(x.dropna().astype(str)),
    axis=1
)

df.sample(10)
# Out:
#       Product_id                                            Product  \
# 7013          16  advanced night repair synchronized recovery co...
# 3426         280                                    treatment toner
# 2157         313  wrinkle warrior™ 2-in-1 plumping moisturizer +...
# 2924         186                         peat miracle revital cream
# 5182         136            gentle foaming cleanser with cottonseed
# 3973          63             clean bee ultra gentle facial cleanser
# 2588         190                            photo finish primerizer
# 3308         159                                 liquid facial soap
# 6703          13                    advanced acne & wrinkle reducer
# 2229         219              resveratrol lift night infusion cream
#
#       Rating_Stars            Brand     Category  \
# 7013             5     ESTÉE LAUDER    Treatment
# 3426             5     AMOREPACIFIC  Moisturizer
# 2157             4  KATE SOMERVILLE  Moisturizer
# 2924             5            BELIF  Moisturizer
# 5182             1          CLARINS     Cleanser
# 3973             5          FARMACY     Cleanser
# 2588             3         SMASHBOX  Moisturizer
# 3308             5         CLINIQUE     Cleanser
# 6703             5            MURAD    Treatment
# 2229             5         CAUDALIE  Moisturizer
#
#                               Skin_sutibility  \
# 7013  combinational dry normal oily sensitive
# 3426  combinational dry normal oily sensitive
# 2157          combinational dry normal oily
# 2924             combinational dry normal
# 5182               combinational   normal
# 3973  combinational dry normal oily sensitive
# 2588          combinational dry normal oily
# 3308  combinational dry normal oily sensitive
# 6703
# 2229  combinational dry normal oily sensitive
#
#                                               Ing_Tfidf  \
# 7013  advanced night repr sync rec cmp division el e...
# 3426  panax ginseng root extract butylene glycol peg...
# 2157  dimethicone propanediol dimethyl isosorbide hy...
# 2924  dipropylene glycol glycerin caprylic capric tr...
# 5182  glycerin stearic acid myristic acid potassium ...
# 3973  sodium lauroyl methyl isethionate cocamidoprop...
# 2588  glycerin dimethicone isopropyl isostearate ppg...
# 3308  sodium laureth sulfate sodium chloride cocamid...
# 6703  dimethicone glycerin ppg buteth hydroxyethyl a...
# 2229  glycerin butylene glycol isononyl isononanoate...
#
#                                           combined_data
# 7013  Treatment combinational dry normal oily sensit...
# 3426  Moisturizer combinational dry normal oily sens...
# 2157  Moisturizer combinational dry normal oily   di...
# 2924  Moisturizer combinational dry normal     dipro...
# 5182  Cleanser combinational   normal     glycerin s...
# 3973  Cleanser combinational dry normal oily sensiti...
# 2588  Moisturizer combinational dry normal oily   gl...
# 3308  Cleanser combinational dry normal oily sensiti...
# 6703  Treatment           dimethicone glycerin ppg b...
# 2229  Moisturizer combinational dry normal oily sens...

# %% [markdown]
# ## Processing Text Data using CountVectorizer

# %%
def recommender (product_name):

#turning our combined data col to a vector to measure its similarity against other vectors
    vec = CountVectorizer()
    vectorized = vec.fit_transform(df['combined_data'])

#calculate cosine sim matrix from the vectors 
    cs = cosine_similarity(vectorized)
#get the name of product 
    #product_name = 'cleanser'
#finding the product id
    product_id = df[df.Product == product_name]['Product_id'].values[0]

#create enumerations for similarity scores and sort it 
    score = list(enumerate(cs[product_id]))
    sorted_score = sorted(score, key = lambda x:x[1], reverse= True)[1:]
    i = 0
    print ('the 5 most similar product to your choice are:\n ')
    for item in sorted_score:

        product_namef = df[df.Product_id == item[0]]['Product'].values[0]
        print(i+1, product_namef , sorted_score[i][1] )
        i = i+1
        if i == 5:
            break

# %%
recommender('caviar lime acid peel')
# Out:
# the 5 most similar product to your choice are:
#
# 1 rub-a-dub refining peel gel 0.5413643428790968
# 2 black tea age-delay firming serum 0.5252548322357349
# 3 retinol youth renewal serum 0.522356412607706
# 4 ceramidin™ cream 0.5157106231293968
# 5 plantscription™ anti-aging cleanser 0.5088344814876714

# %%
recommender('advanced acne & wrinkle reducer')
# Out:
# the 5 most similar product to your choice are:
#
# 1 pore-balance™ facial sauna scrub 0.5304366247201397
# 2 advanced active radiance® serum 0.46539597663355176
# 3 the rice polish foaming enzyme powder 0.4562667580712162
# 4 protein booster skin serum 0.4528947298916564
# 5 ultra repair® cream intense hydration 0.4519846147055686

# %%
recommender('treatment toner')
# Out:
# the 5 most similar product to your choice are:
#
# 1 ultra facial toner 0.6403607079360155
# 2 ultra facial oil-free gel-cream 0.6334971259181912
# 3 deep cleansing exfoliator 0.6303375195568406
# 4 supercleanse™ clearing cream-to-foam cleanser 0.6302148639389665
# 5 anti bac clearing lotion 0.6289780933540263
